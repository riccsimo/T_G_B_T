# %%
import matplotlib.pyplot as plt
# %matplotlib widget
from ipywidgets import *
import numpy as np
import sys
import taurex.log
taurex.log.disableLogging()
from taurex.cache import OpacityCache,CIACache

# %%
# Paths for data
xsec_path = "../../data/atmosphere/xsecs"
cia_path = "../../data/atmosphere/cia/hitran"
phoenix_path = "../../data/atmosphere/phoenix/BT-Settl_M-0.0a+0.0"

#importing crossections
OpacityCache().clear_cache()
OpacityCache().set_opacity_path(xsec_path)
CIACache().set_cia_path(cia_path)

# %%
#(parameters: https://exoplanetarchive.ipac.caltech.edu/overview/WASP-39%20b#planet_WASP-39-b_collapsible)
#Atmospheric model
# Temperature profile
temperature_value = 1166.0  # Kelvin (Teq for isothermal)
#guillot
from taurex.temperature import Guillot2010
guillot = Guillot2010(T_irr=temperature_value) #?????

#isothermal
from taurex.temperature import Isothermal
isothermal = Isothermal(T=temperature_value) #Teq

#Planet
# Planetary parameters
planet_radius = 1.27  # in Jupiter radii
planet_mass = 0.275  # in Jupiter masses
from taurex.planet import Planet
planet = Planet(planet_radius=planet_radius,planet_mass=planet_mass)

#star
# Stellar parameters
star_temperature = 5400.0  # Kelvin
star_radius = 0.895  # in Solar radii

from taurex.stellar import BlackbodyStar
from taurex.stellar import PhoenixStar
star = BlackbodyStar(temperature=star_temperature,radius=star_radius) #ideal blackbody
anotherstar = PhoenixStar(phoenix_path=phoenix_path,
                          temperature=star_temperature,radius=star_radius) #considering stellar atmosphere

#chemistry
fill_gases = ['H2', 'He']
ratio = 0.172

gas_names = ['H2O', 'CH4', 'CO2', 'CO']
#Main components
from taurex.chemistry import TaurexChemistry
chemistry = TaurexChemistry(fill_gases=fill_gases,ratio=ratio)

#others

# Set a random seed for reproducibility
np.random.seed(45)

# Create random values for the abbundances
basis = np.round(np.random.uniform(0, 10, 4),3)  # 4 random numbers between 0 and 10
exponent = -np.random.randint(3, 8, 4)   # 4 random integers between 2 and 8 (inclusive)

mix_ratio = [basis[0]*10.0**(exponent[3]),
             basis[1]*10.0**(exponent[2]),
             basis[2]*10.0**(exponent[1]),
             basis[3]*10.0**(exponent[0])]

print('*************************\n'
    f'Random mixing ratios:\n'
      f'{gas_names[0]}: {mix_ratio[0]:.3e}\n'
      f'{gas_names[1]}: {mix_ratio[1]:.3e}\n'
      f'{gas_names[2]}: {mix_ratio[2]:.3e}\n'
      f'{gas_names[3]}: {mix_ratio[3]:.3e}\n'
      '*************************')

from taurex.chemistry import ConstantGas
h2o = ConstantGas(gas_names[0],mix_ratio=mix_ratio[0])
chemistry.addGas(h2o)
ch4 = ConstantGas(gas_names[1],mix_ratio=mix_ratio[1])
chemistry.addGas(ch4)
co2 = ConstantGas(gas_names[2],mix_ratio=mix_ratio[2])
chemistry.addGas(co2)
co = ConstantGas(gas_names[3],mix_ratio=mix_ratio[3])
chemistry.addGas(co)

#all toghether
temperature_type = "isothermal"
# Pressure profile
atm_min_pressure = 1e-0  # bar
atm_max_pressure = 1e6  # bar
nlayers = 30

from taurex.model import TransmissionModel
tm = TransmissionModel(planet=planet,
                       temperature_profile=isothermal,
                       chemistry=chemistry,
                       star=anotherstar,
                        atm_min_pressure=atm_min_pressure,
                       atm_max_pressure=atm_max_pressure,
                       nlayers=nlayers)
# Out:
# Numba not installed, using numpy instead
# WARNING: VerifyWarning: Invalid keyword for column 1: Column disp option (TDISPn) failed verification: Format E is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# WARNING: VerifyWarning: Invalid keyword for column 2: Column disp option (TDISPn) failed verification: Format E is not recognized. The invalid value will be ignored for the purpose of formatting the data in this column. [astropy.io.fits.column]
# *************************
# Random mixing ratios:
# H2O: 9.890e-03
# CH4: 5.495e-04
# CO2: 2.814e-07
# CO: 7.730e-07
# *************************

# %%
# Model type
model_type = "transmission"

#physical phenomena
#absorption
from taurex.contributions import AbsorptionContribution
tm.add_contribution(AbsorptionContribution())

#CIA (collisional induced absorption)
from taurex.contributions import CIAContribution
# Contributions
cia_pairs = ['H2-H2', 'H2-He']
tm.add_contribution(CIAContribution(cia_pairs=cia_pairs))

#scattering
from taurex.contributions import RayleighContribution
tm.add_contribution(RayleighContribution())

tm.build()

# %%
#running the model
tm.model()

# %%
from taurex.optimizer.nestle import NestleOptimizer
opt = NestleOptimizer(num_live_points=50)
#list of possible parameters that we can retrive from this model
list(tm.fittingParameters.keys())
# Out:
# ['planet_mass',
#  'planet_radius',
#  'planet_distance',
#  'planet_sma',
#  'atm_min_pressure',
#  'atm_max_pressure',
#  'T',
#  'H2O',
#  'CH4',
#  'CO2',
#  'CO',
#  'He_H2']

# %%
from taurex.data.spectrum.observed import ObservedSpectrum
#adding gaussian noise to the artificial spectrum

obs = ObservedSpectrum('WASP-39b_assignment3_taskA_spectrum.dat')

noise = np.random.normal(loc=0.0, scale=obs.errorBar*0.5, size=len(obs.spectrum))

obs_flux = obs.spectrum + noise

# Plot 
plt.figure(figsize=(10, 6))
plt.errorbar(
    obs.wavelengthGrid, obs_flux, obs.errorBar, fmt='o', color='blue', markersize=2,
    ecolor='lightblue', elinewidth=1, capsize=2, label="Transmission Spectrum with Noise"
)
plt.xlabel("Wavelength (micron)")
plt.ylabel("$(R_p/R_s)^2$")
plt.title("Transmission Spectrum with Gaussian Noise")
plt.grid(True, linestyle="--", linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.xscale('log')
plt.show()


#saving the noisy spectrum in a file .dat

spectrum_data = np.column_stack((obs.wavelengthGrid, obs_flux, obs.errorBar))
np.savetxt('artificial_noise_spectrum.dat', spectrum_data, header="wavelength(micron) (rp/rs)^2 std((rp/rs)^2)", fmt="%.8e")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#obs = ObservedSpectrum('artificial_noise_spectrum.dat')
obs = ObservedSpectrum('WASP-39b_assignment3_taskA_spectrum.dat')

#binned for plotting
obin = obs.create_binner()

opt.set_model(tm)
opt.set_observed(obs)

# %%
#Choosing the parameters to fit and the boudaries
opt.enable_fit('H2O')
opt.set_boundary('H2O',[1e-4,1e-1])
opt.enable_fit('T')
opt.set_boundary('T',[1000,2000])
opt.enable_fit('planet_radius')
opt.set_boundary('planet_radius',[0.8,2.0])

# %%
#retrival
solution = opt.fit()
taurex.log.disableLogging()
# Out:
# it=   412 logz=-7634873.95130151
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 #retrival
# ----> 2 solution = opt.fit()
#       3 taurex.log.disableLogging()
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/optimizer/optimizer.py:534, in Optimizer.fit(self, output_size)
#     532 disableLogging()
#     533 # Compute fit here
# --> 534 self.compute_fit()
#     536 enableLogging()
#     537 end_time = time.time()
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/optimizer/nestle.py:119, in NestleOptimizer.compute_fit(self)
#     115 ndims = ndim  # two parameters
#     117 t0 = time.time()
# --> 119 res = nestle.sample(
#     120     self.log_likelihood,
#     121     nestle_uniform_prior,
#     122     ndims,
#     123     method="multi",
#     124     npoints=self.numLivePoints,
#     125     dlogz=self.tolerance,
#     126     callback=nestle.print_progress,
#     127 )
#     129 res = t.cast(nestle.Result, res)
#     130 t1 = time.time()
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/nestle.py:929, in sample(loglikelihood, prior_transform, ndim, npoints, method, update_interval, npdim, maxiter, maxcall, dlogz, decline_factor, rstate, callback, **options)
#     925     since_update = 0
#     927 # Choose a new point from within the likelihood constraint
#     928 # (having logl > loglstar).
# --> 929 u, v, logl, nc = sampler.new_point(loglstar)
#     931 # replace worst point with new point
#     932 active_u[worst] = u
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/nestle.py:670, in MultiEllipsoidSampler.new_point(self, loglstar)
#     668         break
#     669 v = self.prior_transform(u)
# --> 670 logl = self.loglikelihood(v)
#     671 ncall += 1
#     672 if logl >= loglstar:
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/optimizer/optimizer.py:305, in Optimizer.log_likelihood(self, parameters)
#     302 data = self._observed.spectrum
#     303 datastd = self._observed.errorBar
# --> 305 chi_t = self.chisq_trans(parameters, data, datastd)
#     306 loglike = -np.sum(np.log(datastd * SQRTPI)) - 0.5 * chi_t
#     307 return loglike
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/optimizer/optimizer.py:472, in Optimizer.chisq_trans(self, fit_params, data, datastd)
#     468 obs_bins = self._observed.wavenumberGrid
#     470 try:
#     471     _, final_model, _, _ = self._binner.bin_model(
# --> 472         self._model.model(wngrid=obs_bins)
#     473     )
#     474 except InvalidModelException:
#     475     return np.nan
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/model/simplemodel.py:525, in SimpleForwardModel.model(self, wngrid, cutoff_grid)
#     522     contrib.prepare(self, native_grid)
#     524 # Compute path integral
# --> 525 absorp, tau = self.path_integral(native_grid, False)
#     527 return native_grid, absorp, tau, None
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/model/transmission.py:185, in TransmissionModel.path_integral(self, wngrid, return_contrib)
#     183             break
#     184         self.debug("Adding contribution from %s", contrib.name)
# --> 185         contrib.contribute(
#     186             self, 0, end_k, layer, layer, density_profile, tau, path_length=dl
#     187         )
#     189 self.debug("tau %s %s", tau, tau.shape)
#     191 absorption, tau = self.compute_absorption(tau, dz)
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/contributions/absorption.py:212, in AbsorptionContribution.contribute(self, model, start_horz_layer, end_horz_layer, density_offset, layer, density, tau, path_length)
#     198     contribute_ktau(
#     199         start_horz_layer,
#     200         end_horz_layer,
#    (...)
#     209         self.weights.shape[0],
#     210     )
#     211 else:
# --> 212     super().contribute(
#     213         model,
#     214         start_horz_layer,
#     215         end_horz_layer,
#     216         density_offset,
#     217         layer,
#     218         density,
#     219         tau,
#     220         path_length,
#     221     )
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/contributions/contribution.py:292, in Contribution.contribute(self, model, start_layer, end_layer, density_offset, layer, density, tau, path_length)
#     281 self.debug("SIGMA %s", self.sigma_xsec.shape)
#     282 self.debug(
#     283     " %s %s %s %s %s %s %s",
#     284     start_layer,
#    (...)
#     290     self._ngrid,
#     291 )
# --> 292 contribute_tau(
#     293     start_layer,
#     294     end_layer,
#     295     density_offset,
#     296     self.sigma_xsec,
#     297     density,
#     298     path_length,
#     299     self._nlayers,
#     300     self._ngrid,
#     301     layer,
#     302     tau,
#     303 )
#     304 self.debug("DONE")
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/contributions/contribution.py:102, in contribute_tau_numpy(startk, endk, density_offset, sigma, density, path, nlayers, ngrid, layer, tau)
#      99 _density = density[startk + density_offset : endk + density_offset, None]
#     100 _sigma = sigma[startk + layer : endk + layer, :]
# --> 102 tau[layer, :] += np.sum(_sigma * _path * _density, axis=0)
#     104 return tau
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2172, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2102     """
#    2103     Clip (limit) the values in an array.
#    2104
#    (...)
#    2167
#    2168     """
#    2169     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2172 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2173                     initial=None, where=None):
#    2174     return (a, out)
#    2177 @array_function_dispatch(_sum_dispatcher)
#    2178 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2179         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %%
for solution,optimized_map,optimized_value,values in opt.get_solution():
    opt.update_model(optimized_map)
    plt.figure()
    plt.errorbar(obs.wavelengthGrid,obs.spectrum,obs.errorBar,label='Obs')
    plt.plot(obs.wavelengthGrid,obin.bin_model(tm.model(obs.wavenumberGrid))[1],label='TM')
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 for solution,optimized_map,optimized_value,values in opt.get_solution():
#       2     opt.update_model(optimized_map)
#       3     plt.figure()
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/taurex/optimizer/nestle.py:189, in NestleOptimizer.get_solution(self)
#     187 opt_map = self.fit_values
#     188 opt_values = self.fit_values
# --> 189 for k, v in self._nestle_output["solution"]["fitparams"].items():
#     190     # if k.endswith('_derived'):
#     191     #     continue
#     192     idx = names.index(k)
#     193     opt_map[idx] = v["map"]
#
# TypeError: 'NoneType' object is not subscriptable
