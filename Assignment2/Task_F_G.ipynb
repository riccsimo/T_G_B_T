# %%
from daneel.parameters import Parameters
from daneel.detection import *
# Out:
# 2024-11-29 17:46:28.494900: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-29 17:46:28.498835: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-29 17:46:28.510566: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732898788.530094  134077 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732898788.535498  134077 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
NN_simple_params = {
                "path_to_train_dataset": "../../data/kepler/data_no_injection/exoTrain.csv",
                "path_to_dev_dataset": "../../data/kepler/data_no_injection/exoTest.csv",
                "complex_model": False,
                "load_model": False,
                "render_plot": True,
                "weights_path": False,
                "save_weights": False
}


NN_complex_params = {
                "path_to_train_dataset": "../../data/kepler/data_no_injection/exoTrain.csv",
                "path_to_dev_dataset": "../../data/kepler/data_no_injection/exoTest.csv",
                "complex_model": True,
                "load_model": False,
                "render_plot": True,
                "weights_path": False,
                "save_weights": False
}

NN_simple_injected_params = {
                "path_to_train_dataset": "../../data/kepler/data_injected/exoTrain.csv",
                "path_to_dev_dataset": "../../data/kepler/data_injected/exoTest.csv",
                "complex_model": False,
                "load_model": False,
                "render_plot": True,
                "weights_path": False,
                "save_weights": False
}


NN_complex_injected_params = {
                "path_to_train_dataset": "../../data/kepler/data_injected/exoTrain.csv",
                "path_to_dev_dataset": "../../data/kepler/data_injected/exoTest.csv",
                "complex_model": True,
                "load_model": False,
                "render_plot": True,
                "weights_path": False,
                "save_weights": False
}

# %%
NN_simple = NNExoplanetDetector(NN_simple_params)
NN_complex = NNExoplanetDetector(NN_complex_params)
NN_simple_injected = NNExoplanetDetector(NN_simple_injected_params)
NN_complex_injected = NNExoplanetDetector(NN_complex_injected_params)

# %%
#NN_simple.run()

# %%
#NN_complex.run()

# %%
NN_complex_injected.run()
# Out:
# Loading datasets...
# Loaded datasets!
# Applying Fourier...
# Normalizing...
# Applying Gaussian Filter...
# Standardizing...
# Finished Processing!
# X_train.shape:  (5087, 1598)
# Y_train.shape:  (5087,)
# X_dev.shape:  (570, 1598)
# Y_dev.shape:  (570,)
# Number of features:  1598
# Number of exoplanets in training set:  2861
# Number of exoplanets in development set:  316
# 2024-11-29 17:46:34.708144: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Training...
# Epoch 1/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5002 - loss: 0.7019
# Epoch 2/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5008 - loss: 0.6947
# Epoch 3/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5137 - loss: 0.6932
# Epoch 4/50
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5077 - loss: 0.6928
# Epoch 5/50
# ...

# %%
#NN_simple_injected.run()
