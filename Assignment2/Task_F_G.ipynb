# %%
from daneel.parameters import Parameters
from daneel.detection import *
# Out:
# 2024-11-29 10:22:26.411154: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732872146.431303  416503 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732872146.436639  416503 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-29 10:22:26.459649: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
NN_simple_params = {
                "path_to_train_dataset": "../../data/kepler/data_no_injection/exoTrain.csv",
                "path_to_dev_dataset": "../../data/kepler/data_no_injection/exoTest.csv",
                "complex_model": False,
                "load_model": False,
                "render_plot": True,
                "weights_path": False,
                "save_weights": False
}


NN_complex_params = {
                "path_to_train_dataset": "../../data/kepler/data_no_injection/exoTrain.csv",
                "path_to_dev_dataset": "../../data/kepler/data_no_injection/exoTest.csv",
                "complex_model": True,
                "load_model": False,
                "render_plot": True,
                "weights_path": False,
                "save_weights": False
}

# %%
NN_simple = NNExoplanetDetector(NN_simple_params)
NN_complex = NNExoplanetDetector(NN_complex_params)

# %%
NN_simple.run()
# Out:
# Loading datasets...
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 NN_simple.run()
#
# File ~/ComputationalAstro/comp_astro_24/src/daneel/detection/NN_exoplanets.py:214, in NNExoplanetDetector.run(self)
#     212 def run(self):
#     213     # Execute the steps
# --> 214     self.load_data()
#     215     self.prepare_model()
#     216     self.train()
#
# File ~/ComputationalAstro/comp_astro_24/src/daneel/detection/NN_exoplanets.py:83, in NNExoplanetDetector.load_data(self)
#      81 # Loading datasets
#      82 print("Loading datasets...")
# ---> 83 df_train = pd.read_csv(self.path_to_train_dataset, encoding="ISO-8859-1")
#      84 df_dev = pd.read_csv(self.path_to_dev_dataset, encoding="ISO-8859-1")
#      86 # Generate X and Y dataframe sets
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/miniconda3/envs/ComputationalAstro/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
NN_complex.run()
# Out:
# Loading datasets...
# Loaded datasets!
# Applying Fourier...
# Normalizing...
# Applying Gaussian Filter...
# Standardizing...
# Finished Processing!
# X_train.shape:  (5087, 1598)
# Y_train.shape:  (5087,)
# X_dev.shape:  (570, 1598)
# Y_dev.shape:  (570,)
# Number of features:  1598
# Number of exoplanets in training set:  37
# Number of exoplanets in development set:  5
# I0000 00:00:1732872164.138912  416503 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4080 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Training...
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732872166.483488  416648 service.cc:148] XLA service 0x7f8d4000b970 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732872166.483536  416648 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti, Compute Capability 7.5
# 2024-11-29 10:22:46.511836: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732872166.680112  416648 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  46/316 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6548 - loss: 0.5309
# I0000 00:00:1732872167.307988  416648 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7729 - loss: 0.4460
# Epoch 2/50
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8254 - loss: 0.4003
# Epoch 3/50
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7994 - loss: 0.4211
# Epoch 4/50
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.