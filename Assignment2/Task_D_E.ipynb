# %%
from daneel.parameters import Parameters
from daneel.detection import *
# Out:
# 2024-11-29 09:16:03.599022: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732868163.756954  396789 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732868163.802776  396789 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-29 09:16:04.220032: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
linear = {  "path_to_train_dataset": "../../data/kepler/data_no_injection/exoTrain.csv",
            "path_to_dev_dataset": "../../data/kepler/data_no_injection/exoTest.csv",
            "kernel": 'linear_svc',
            "degree": 4}

gaussian = {  "path_to_train_dataset": "../../data/kepler/data_no_injection/exoTrain.csv",
            "path_to_dev_dataset": "../../data/kepler/data_no_injection/exoTest.csv",
            "kernel": 'rbf',
            "degree": 4}

poly = {  "path_to_train_dataset": "../../data/kepler/data_no_injection/exoTrain.csv",
            "path_to_dev_dataset": "../../data/kepler/data_no_injection/exoTest.csv",
            "kernel": 'poly',
            "degree": 4}

# %%
SVM_linear = SVMExoplanetDetector(linear)
SVM_gaussian = SVMExoplanetDetector(gaussian)
SVM_poly = SVMExoplanetDetector(poly)

# %%
SVM_linear.run()
# Out:
# Loading datasets...
# Loaded datasets!
# Applying Fourier...
# Normalizing...
# Applying Gaussian Filter...
# Standardizing...
# Finished Processing!
# X_train.shape:  (5087, 1598)
# Y_train.shape:  (5087,)
# X_dev.shape:  (570, 1598)
# Y_dev.shape:  (570,)
# Number of features:  1598
# Number of exoplanets in training set:  37
# Number of exoplanets in development set:  5
# Model initialized with kernel='linear_svc'
# Training...
# Finished Training!
#
# Train Set Error 0.00019657951641438576
# Dev Set Error 0.01403508771929829
# ------------
# Precision - Train Set 0.9736842105263158
# Precision - Dev Set 0.38461538461538464
# ------------
# Recall - Train Set 1.0
# Recall - Dev Set 1.0
# ------------
# Confusion Matrix - Train Set
# [[5049    1]
#  [   0   37]]
# Confusion Matrix - Dev Set
# [[557   8]
#  [  0   5]]
# ------------
# Classification Report - Train Set
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      5050
# ...

# %%
SVM_gaussian.run()
# Out:
# Loading datasets...
# Loaded datasets!
# Applying Fourier...
# Normalizing...
# Applying Gaussian Filter...
# Standardizing...
# Finished Processing!
# X_train.shape:  (5087, 1598)
# Y_train.shape:  (5087,)
# X_dev.shape:  (570, 1598)
# Y_dev.shape:  (570,)
# Number of features:  1598
# Number of exoplanets in training set:  37
# Number of exoplanets in development set:  5
# Model initialized with kernel='rbf'
# Training...
# Finished Training!
#
# Train Set Error 0.00019657951641438576
# Dev Set Error 0.00877192982456143
# ------------
# Precision - Train Set 1.0
# Precision - Dev Set 0.0
# ------------
# Recall - Train Set 0.972972972972973
# Recall - Dev Set 0.0
# ------------
# Confusion Matrix - Train Set
# [[5050    0]
#  [   1   36]]
# Confusion Matrix - Dev Set
# [[565   0]
#  [  5   0]]
# ------------
# Classification Report - Train Set
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      5050
# ...

# %%
SVM_poly.run()
# Out:
# Loading datasets...
# Loaded datasets!
# Applying Fourier...
# Normalizing...
# Applying Gaussian Filter...
# Standardizing...
# Finished Processing!
# X_train.shape:  (5087, 1598)
# Y_train.shape:  (5087,)
# X_dev.shape:  (570, 1598)
# Y_dev.shape:  (570,)
# Number of features:  1598
# Number of exoplanets in training set:  37
# Number of exoplanets in development set:  5
# Model initialized with kernel='poly'
# Polynomial degree: 4
# Training...
# Finished Training!
#
# Train Set Error 0.0
# Dev Set Error 0.019298245614035037
# ------------
# Precision - Train Set 1.0
# Precision - Dev Set 0.0
# ------------
# Recall - Train Set 1.0
# Recall - Dev Set 0.0
# ------------
# Confusion Matrix - Train Set
# [[5050    0]
#  [   0   37]]
# Confusion Matrix - Dev Set
# [[559   6]
#  [  5   0]]
# ------------
# Classification Report - Train Set
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      5050
# ...

# %%
linear_injected = {  "path_to_train_dataset": "../../data/kepler/data_injected/exoTrain.csv",
            "path_to_dev_dataset": "../../data/kepler/data_injected/exoTest.csv",
            "kernel": 'linear_svc',
            "degree": 4}

gaussian_injected = {  "path_to_train_dataset": "../../data/kepler/data_injected/exoTrain.csv",
            "path_to_dev_dataset": "../../data/kepler/data_injected/exoTest.csv",
            "kernel": 'rbf',
            "degree": 4}

poly_injected = {  "path_to_train_dataset": "../../data/kepler/data_injected/exoTrain.csv",
            "path_to_dev_dataset": "../../data/kepler/data_injected/exoTest.csv",
            "kernel": 'poly',
            "degree": 4}

# %%
SVM_linear_injected = SVMExoplanetDetector(linear_injected)
SVM_gaussian_injected = SVMExoplanetDetector(gaussian_injected)
SVM_poly_injected = SVMExoplanetDetector(poly_injected)

# %%
SVM_linear_injected.run()
# Out:
# Loading datasets...
# Loaded datasets!
# Applying Fourier...
# Normalizing...
# Applying Gaussian Filter...
# Standardizing...
# Finished Processing!
# X_train.shape:  (5087, 1598)
# Y_train.shape:  (5087,)
# X_dev.shape:  (570, 1598)
# Y_dev.shape:  (570,)
# Number of features:  1598
# Number of exoplanets in training set:  2861
# Number of exoplanets in development set:  316
# Model initialized with kernel='linear_svc'
# Training...
# Finished Training!
#
# Train Set Error 0.4356202083742874
# Dev Set Error 0.4842105263157894
# ------------
# Precision - Train Set 0.6281287246722288
# Precision - Dev Set 0.5485436893203883
# ------------
# Recall - Train Set 0.552603984620762
# Recall - Dev Set 0.7151898734177216
# ------------
# Confusion Matrix - Train Set
# [[1290  936]
#  [1280 1581]]
# Confusion Matrix - Dev Set
# [[ 68 186]
#  [ 90 226]]
# ------------
# Classification Report - Train Set
#               precision    recall  f1-score   support
#
# ...

# %%
SVM_gaussian_injected.run()
# Out:
# Loading datasets...
# Loaded datasets!
# Applying Fourier...
# Normalizing...
# Applying Gaussian Filter...
# Standardizing...
# Finished Processing!
# X_train.shape:  (5087, 1598)
# Y_train.shape:  (5087,)
# X_dev.shape:  (570, 1598)
# Y_dev.shape:  (570,)
# Number of features:  1598
# Number of exoplanets in training set:  2861
# Number of exoplanets in development set:  316
# Model initialized with kernel='rbf'
# Training...
# Finished Training!
#
# Train Set Error 0.4330646746609004
# Dev Set Error 0.44561403508771935
# ------------
# Precision - Train Set 0.5653296266878475
# Precision - Dev Set 0.5543859649122806
# ------------
# Recall - Train Set 0.9951066060817896
# Recall - Dev Set 1.0
# ------------
# Confusion Matrix - Train Set
# [[  37 2189]
#  [  14 2847]]
# Confusion Matrix - Dev Set
# [[  0 254]
#  [  0 316]]
# ------------
# Classification Report - Train Set
#               precision    recall  f1-score   support
#
# ...

# %%
SVM_poly_injected.run()
# Out:
# Loading datasets...
# Loaded datasets!
# Applying Fourier...
# Normalizing...
# Applying Gaussian Filter...
# Standardizing...
# Finished Processing!
# X_train.shape:  (5087, 1598)
# Y_train.shape:  (5087,)
# X_dev.shape:  (570, 1598)
# Y_dev.shape:  (570,)
# Number of features:  1598
# Number of exoplanets in training set:  2861
# Number of exoplanets in development set:  316
# Model initialized with kernel='poly'
# Polynomial degree: 4
# Training...
# Finished Training!
#
# Train Set Error 0.4287399252997838
# Dev Set Error 0.45964912280701753
# ------------
# Precision - Train Set 0.5687980574666127
# Precision - Dev Set 0.5597345132743363
# ------------
# Recall - Train Set 0.9825235931492485
# Recall - Dev Set 0.8006329113924051
# ------------
# Confusion Matrix - Train Set
# [[  95 2131]
#  [  50 2811]]
# Confusion Matrix - Dev Set
# [[ 55 199]
#  [ 63 253]]
# ------------
# Classification Report - Train Set
#               precision    recall  f1-score   support
#
# ...
